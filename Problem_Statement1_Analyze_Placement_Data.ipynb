# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Placement_Data_Full_Class.csv")

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.shape
# Out:
# (215, 15)

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
df["status"].replace("Placed",1)
# Out:
# 0               1
# 1               1
# 2               1
# 3      Not Placed
# 4               1
#           ...
# 210             1
# 211             1
# 212             1
# 213             1
# 214    Not Placed
# Name: status, Length: 215, dtype: object

# %%
df1=df.replace(to_replace="Not Placed",
           value=0)
df1
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
df1=df1.replace(to_replace="Placed",
           value=1)
df1
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
print(df1['ssc_p'].corr(df1['status']))
# Out:
# 0.6078887335215233

# %%
print(df1['hsc_p'].corr(df1['status']))
# Out:
# 0.49122794449410684

# %%
print(df1['mba_p'].corr(df1['status']))
# Out:
# 0.07692164904759434

# %% [markdown]
# Graphical Representation of factors affecting the placement of a student

# %%
# %matplotlib inline
plt.xlabel('gender')
plt.ylabel('status')
plt.scatter(df.gender,df.status)

# %%
# %matplotlib inline
plt.xlabel('ssc_p')
plt.ylabel('status')
plt.scatter(df.ssc_p,df.status)

# %%
# %matplotlib inline
plt.xlabel('hsc_p')
plt.ylabel('status')
plt.scatter(df.hsc_p,df.status)

# %%
# %matplotlib inline
plt.xlabel('degree_p')
plt.ylabel('status')
plt.scatter(df.degree_p,df.status)

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c)
# Out:
# <ipython-input-132-95ebd312c200>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
# <AxesSubplot: >

# %%
plt.xlabel('mba_p')
plt.ylabel('status')


plt.scatter(df['mba_p'],df['status'] , color='green')

# %% [markdown]
# degree specializations are in high demand in the industry  95 in Mkt&Fin are placed

# %%
df.specialisation
# Out:
# 0       Mkt&HR
# 1      Mkt&Fin
# 2      Mkt&Fin
# 3       Mkt&HR
# 4      Mkt&Fin
#         ...
# 210    Mkt&Fin
# 211    Mkt&Fin
# 212    Mkt&Fin
# 213     Mkt&HR
# 214     Mkt&HR
# Name: specialisation, Length: 215, dtype: object

# %%
s.max()
# Out:
#                 sl_no gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  degree_p  \
# specialisation
# Mkt&Fin           213      M   87.0  Others   97.7  Others  Science      85.0
# Mkt&HR            215      M   89.4  Others   91.0  Others  Science      91.0
#
#                 degree_t workex  etest_p  mba_p  status    salary
# specialisation
# Mkt&Fin         Sci&Tech    Yes     98.0  77.89  Placed  940000.0
# Mkt&HR          Sci&Tech    Yes     97.0  76.26  Placed  450000.0

# %%
p= df.groupby('status')
p

# %%
for status, status_df in p:
    print(status)
    print(status_df)
# Out:
# Not Placed
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
x=p.get_group('Placed')
x
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
# %matplotlib inline
x.plot()
# Out:
# <AxesSubplot: >

# %%
sp= x.groupby('specialisation')
sp

# %%
for specialisation, specialisation_df in sp:
    print(specialisation)
    print(specialisation_df)
# Out:
# Mkt&Fin
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 207    208      M  83.33  Central  78.00   Others  Commerce     61.00
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
sp.max()
# Out:
#                 sl_no gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  degree_p  \
# specialisation
# Mkt&Fin           213      M   87.0  Others   97.7  Others  Science      85.0
# Mkt&HR            214      M   89.4  Others   91.0  Others  Science      91.0
#
#                 degree_t workex  etest_p  mba_p  status    salary
# specialisation
# Mkt&Fin         Sci&Tech    Yes     98.0  77.89  Placed  940000.0
# Mkt&HR          Sci&Tech    Yes     97.0  76.26  Placed  450000.0

# %%
sp.describe()
# Out:
#                sl_no                                                         \
#                count        mean        std  min   25%    50%    75%    max
# specialisation
# Mkt&Fin         95.0  103.557895  60.910069  2.0  59.5   96.0  151.5  213.0
# Mkt&HR          53.0  112.830189  60.389676  1.0  55.0  119.0  161.0  214.0
#
#                ssc_p             ...  mba_p        salary                 \
#                count       mean  ...    75%    max  count           mean
# specialisation                   ...
# Mkt&Fin         95.0  72.234105  ...  67.09  77.89   95.0  298852.631579
# Mkt&HR          53.0  70.802642  ...  64.36  76.26   53.0  270377.358491
#
#                                                                        \
#                           std       min       25%       50%       75%
# specialisation
# Mkt&Fin         108190.530165  200000.0  240000.0  270000.0  300000.0
# Mkt&HR           54784.271471  200000.0  240000.0  255000.0  300000.0
#
#
# ...

# %%
y=p.get_group('Not Placed')
y
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
# %matplotlib inline
y.plot()
# Out:
# <AxesSubplot: >

# %%
sp1= y.groupby('specialisation')
sp1

# %%
for specialisation, specialisation_df in sp1:
    print(specialisation)
    print(specialisation_df)
# Out:
# Mkt&Fin
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 17      18      F  55.00  Central  67.00  Central  Commerce     64.00
# 25      26      F  52.58   Others  54.60  Central  Commerce     50.20
# 29      30      M  62.00  Central  67.00  Central  Commerce     58.00
# 36      37      M  51.00  Central  44.00  Central  Commerce     57.00
# 42      43      M  49.00   Others  39.00  Central   Science     65.00
# 82      83      M  63.00  Central  67.00  Central  Commerce     74.00
# 97      98      F  70.50  Central  62.50   Others  Commerce     61.00
# 99     100      M  54.00  Central  82.00   Others  Commerce     63.00
# 106    107      M  61.08   Others  50.00   Others   Science     54.00
# ...

# %%
sp1.max()
# Out:
#                 sl_no gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  degree_p  \
# specialisation
# Mkt&Fin           207      M   70.5  Others  82.00  Others  Science      79.0
# Mkt&HR            215      M   77.8  Others  74.66  Others  Science      77.5
#
#                 degree_t workex  etest_p  mba_p      status  salary
# specialisation
# Mkt&Fin         Sci&Tech    Yes    97.00  75.71  Not Placed     NaN
# Mkt&HR          Sci&Tech    Yes    92.66  72.14  Not Placed     NaN

# %%
sp1.describe()
# Out:
#                sl_no                                                           \
#                count        mean        std  min    25%    50%     75%    max
# specialisation
# Mkt&Fin         25.0  112.520000  71.407353  6.0  37.00  131.0  183.00  207.0
# Mkt&HR          42.0  109.261905  63.193879  4.0  52.25  103.5  169.75  215.0
#
#                ssc_p             ...  mba_p        salary                   \
#                count       mean  ...    75%    max  count mean std min 25%
# specialisation                   ...
# Mkt&Fin         25.0  56.526400  ...  65.33  75.71    0.0  NaN NaN NaN NaN
# Mkt&HR          42.0  58.149762  ...  65.37  72.14    0.0  NaN NaN NaN NaN
#
#
#                50% 75% max
# specialisation
# Mkt&Fin        NaN NaN NaN
# Mkt&HR         NaN NaN NaN
#
# [2 rows x 56 columns]
